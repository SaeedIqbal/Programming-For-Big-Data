# %%
import numpy as np
import pandas as pd

# %%
ar = np.array([['','Book Title','Price'],[1,'Java',36.12],[2,'Networking',63.87],[3,'Python',45.12],[4,'C++',789.12]])

# %%
ar
# Out:
# array([['', 'Book Title', 'Price'],
#        ['1', 'Java', '36.12'],
#        ['2', 'Networking', '63.87'],
#        ['3', 'Python', '45.12'],
#        ['4', 'C++', '789.12']], dtype='<U10')

# %%
bka = pd.DataFrame(data=ar[1:,1:],index=ar[1:,0],columns=ar[0,1:])

# %%
bka.head()
# Out:
#    Book Title   Price
# 1        Java   36.12
# 2  Networking   63.87
# 3      Python   45.12
# 4         C++  789.12

# %%
print(bka)
# Out:
#    Book Title   Price
# 1        Java   36.12
# 2  Networking   63.87
# 3      Python   45.12
# 4         C++  789.12

# %%
bka.iloc[2]
# Out:
# Book Title    Python
# Price          45.12
# Name: 3, dtype: object

# %%
bka['Book Title']
# Out:
# 1          Java
# 2    Networking
# 3        Python
# 4           C++
# Name: Book Title, dtype: object

# %%
bka['Price']
# Out:
# 1     36.12
# 2     63.87
# 3     45.12
# 4    789.12
# Name: Price, dtype: object

# %% [markdown]
# # Data Filtering Using Pandas

# %%
f = pd.read_csv('euro.csv',sep=',')

# %%
f.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
f
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
f['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
f.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
f.shape
# Out:
# (16, 35)

# %%
f.shape[0]
# Out:
# 16

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
# Team                          16 non-null object
# Goals                         16 non-null int64
# Shots on target               16 non-null int64
# Shots off target              16 non-null int64
# Shooting Accuracy             16 non-null object
# % Goals-to-shots              16 non-null object
# Total shots (inc. Blocked)    16 non-null int64
# Hit Woodwork                  16 non-null int64
# Penalty goals                 16 non-null int64
# Penalties not scored          16 non-null int64
# Headed goals                  16 non-null int64
# Passes                        16 non-null int64
# Passes completed              16 non-null int64
# Passing Accuracy              16 non-null object
# Touches                       16 non-null int64
# Crosses                       16 non-null int64
# Dribbles                      16 non-null int64
# ...

# %%
sf = f[['Team','Yellow Cards','Red Cards']]

# %%
sf.head()
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
sf.sort_values(['Yellow Cards','Red Cards'], ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 6                Greece             9          1
# 0               Croatia             9          0
# 9                Poland             7          1
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 11  Republic of Ireland             6          1
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
f[f.Goals > 5]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 5                      0      ...               10                 62.6%
# ...

# %%
file.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
file.shape
# Out:
# (16, 35)

# %%
file.shape
# Out:
# (16, 35)

# %%
file.shape[0]
# Out:
# 16

# %%
file.Team
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %%
file['Yellow Cards']
# Out:
# 0      9
# 1      7
# 2      4
# 3      5
# 4      6
# 5      4
# 6      9
# 7     16
# 8      5
# 9      7
# 10    12
# 11     6
# 12     6
# 13    11
# 14     7
# 15     5
# Name: Yellow Cards, dtype: int64

# %%
file.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 6                Greece      5                8                18
# 9                Poland      2               15                23
# 11  Republic of Ireland      1                7                12
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 13                Spain     12               42                33
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 4                France      3               22                24
# 12               Russia      5                9                31
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# ...

# %%
f.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %%
f.shape[0]
# Out:
# 16

# %%
f.shape
# Out:
# (16, 35)

# %%
f.iloc[2:7,0:5]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 2  Denmark      4               10                10             50.0%
# 3  England      5               11                18             50.0%
# 4   France      3               22                24             37.9%
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
