# %% [markdown]
# # Data Filtering using Pandas

# %%
import pandas as pd

# %%
f = pd.read_csv('euro.csv',sep=',')

# %%
f.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
type(f)
# Out:
# pandas.core.frame.DataFrame

# %%
f.shape
# Out:
# (16, 35)

# %%
print(f)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
f.head(16)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
f.iloc[0:10,0:5]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
# 7           Italy      6               34                45             43.0%
# 8     Netherlands      2               12                36             25.0%
# 9          Poland      2               15                23             39.4%

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
# Team                          16 non-null object
# Goals                         16 non-null int64
# Shots on target               16 non-null int64
# Shots off target              16 non-null int64
# Shooting Accuracy             16 non-null object
# % Goals-to-shots              16 non-null object
# Total shots (inc. Blocked)    16 non-null int64
# Hit Woodwork                  16 non-null int64
# Penalty goals                 16 non-null int64
# Penalties not scored          16 non-null int64
# Headed goals                  16 non-null int64
# Passes                        16 non-null int64
# Passes completed              16 non-null int64
# Passing Accuracy              16 non-null object
# Touches                       16 non-null int64
# Crosses                       16 non-null int64
# Dribbles                      16 non-null int64
# ...

# %%
sf = f[['Team','Yellow Cards','Red Cards']]

# %%
sf.head()
# Out:
#              Team  Yellow Cards  Red Cards
# 0         Croatia             9          0
# 1  Czech Republic             7          0
# 2         Denmark             4          0
# 3         England             5          0
# 4          France             6          0

# %%
sf.head(16)
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
f['Team']
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %%
f.Team
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %%
sf.sort_values(['Yellow Cards','Red Cards'],ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 6                Greece             9          1
# 0               Croatia             9          0
# 9                Poland             7          1
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 11  Republic of Ireland             6          1
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
sf['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
round(sf['Yellow Cards'].mean())
# Out:
# 7

# %%
f[f.Goals > 5]
# Out:
#         Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5    Germany     10               32                32             47.8%
# 7      Italy      6               34                45             43.0%
# 10  Portugal      6               22                42             34.3%
# 13     Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 7              7.5%                         110             2              0
# 10             9.3%                          82             6              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 5                      0      ...               10                 62.6%
# ...

# %%
f[f.Goals < 5]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 4                France      3               22                24
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 11  Republic of Ireland      1                7                12
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 4              37.9%             6.5%                          65
# ...

# %%
f[f.Team.str.startswith('R')]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
#
#     Hit Woodwork  Penalty goals  Penalties not scored      ...       \
# 11             0              0                     0      ...
# 12             2              0                     0      ...
#
#     Saves made  Saves-to-shots ratio  Fouls Won Fouls Conceded  Offsides  \
# 11          17                 65.4%         43             51        11
# 12          10                 77.0%         34             43         4
#
#     Yellow Cards  Red Cards  Subs on  Subs off  Players Used
# 11             6          1       10        10            17
# ...

# %%
f.tail()
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored      ...       \
# 11             0              0                     0      ...
# ...

# %%
f.tail(3)
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 13    Spain     12               42                33             55.9%
# 14   Sweden      5               17                19             47.2%
# 15  Ukraine      2                7                26             21.2%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 13            16.0%                         100             0              1
# 14            13.8%                          39             3              0
# 15             6.0%                          38             0              0
#
#     Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 13                     0      ...               15                 93.8%
# 14                     0      ...                8                 61.6%
# 15                     0      ...               13                 76.5%
#
# ...

# %%
f.loc[f.Team.isin(['England','Italy','Spain']),['Team','Penalty goals','Fouls Won','Offsides']]
# Out:
#        Team  Penalty goals  Fouls Won  Offsides
# 3   England              0         43         6
# 7     Italy              0        101        16
# 13    Spain              1        102        19

# %%
f.loc[f.Team.isin(['England','Italy','Spain'])]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 3   England      5               11                18             50.0%
# 7     Italy      6               34                45             43.0%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 3             17.2%                          40             0              0
# 7              7.5%                         110             2              0
# 13            16.0%                         100             0              1
#
#     Penalties not scored      ...       Saves made  Saves-to-shots ratio  \
# 3                      0      ...               22                 88.1%
# 7                      0      ...               20                 74.1%
# 13                     0      ...               15                 93.8%
#
# ...

# %%
f.describe()
# Out:
#            Goals  Shots on target  Shots off target  \
# count  16.000000        16.000000         16.000000
# mean    4.750000        17.125000         24.937500
# std     2.886751        10.582218         10.680005
# min     1.000000         7.000000         10.000000
# 25%     2.750000         9.750000         18.000000
# 50%     4.500000        13.000000         23.500000
# 75%     5.250000        22.000000         32.250000
# max    12.000000        42.000000         45.000000
#
#        Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# count                   16.000000     16.000000      16.000000
# mean                    54.937500      1.250000       0.187500
# std                     26.065223      1.612452       0.403113
# min                     27.000000      0.000000       0.000000
# 25%                     36.500000      0.000000       0.000000
# 50%                     44.000000      1.000000       0.000000
# ...

# %%
f.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
f.head(16)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
f.groupby(['Goals'])

# %%
f.groupby(['Team']).Goals.mean()
# Out:
# Team
# Croatia                 4
# Czech Republic          4
# Denmark                 4
# England                 5
# France                  3
# Germany                10
# Greece                  5
# Italy                   6
# Netherlands             2
# Poland                  2
# Portugal                6
# Republic of Ireland     1
# Russia                  5
# Spain                  12
# Sweden                  5
# Ukraine                 2
# Name: Goals, dtype: int64
