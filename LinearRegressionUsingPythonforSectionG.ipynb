# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
path = '/home/saeed/house/USA_Housing.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %%
df.shape
# Out:
# (5000, 7)

# %%
#Dependent Varibale  = Y = Price
#Independent Variable = Income, House Age, Number of Rooms, Number of Bedrooms, Address....
sns.distplot(df['Price'])

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
x = df[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population']]
y = df[['Price']]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test ,y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=50)

# %%
x_train.shape
# Out:
# (3500, 5)

# %%
x_test.shape
# Out:
# (1500, 5)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pr = lm.predict(x_test)

# %%
pr
# Out:
# array([[ 631305.05842546],
#        [1231990.56161568],
#        [1539664.80551486],
#        ...,
#        [1251986.62330191],
#        [1036432.95159311],
#        [1553580.80137909]])

# %%
y_test
# Out:
#              Price
# 3431  6.129387e+05
# 2042  1.347083e+06
# 79    1.492011e+06
# 4663  1.223915e+06
# 3640  1.368692e+06
# 65    8.586856e+05
# 1811  9.920531e+05
# 1815  1.170574e+06
# 1727  3.194957e+05
# 4918  1.577850e+06
# 2037  7.345621e+05
# 1461  1.249174e+06
# 3969  7.181870e+05
# 1142  1.247581e+06
# 3411  1.295946e+06
# 3093  1.334537e+06
# 2972  1.599616e+06
# 2665  1.145351e+06
# 1989  1.073356e+06
# 1693  8.735881e+05
# 3432  1.521746e+06
# 245   1.118048e+06
# 4810  1.296121e+06
# 3209  9.870041e+05
# 2163  1.539465e+06
# 2917  2.142897e+06
# 3242  1.081579e+06
# 4344  5.855312e+05
# 1790  1.473278e+06
# 2066  2.050594e+06
# ...            ...
# 4833  1.739761e+06
# 4667  1.455737e+06
# 2859  1.132780e+06
# 4827  9.591021e+05
# 4752  1.795429e+06
# 3171  1.480675e+06
# 3635  1.735340e+06
# 3043  7.102692e+05
# 4802  1.384798e+06
# 3473  1.846350e+06
# 2863  1.664302e+06
# 3971  1.333996e+06
# 4586  1.523802e+06
# 2855  7.924495e+05
# 604   1.347622e+06
# 2503  1.492787e+06
# 3138  1.898169e+06
# 2166  1.131041e+06
# 3583  1.483686e+06
# 2441  1.496177e+06
# 925   1.116193e+06
# 124   1.300265e+06
# 4938  1.213352e+06
# 144   1.230149e+06
# 1768  1.401768e+06
# 4239  8.954410e+05
# 1447  1.035171e+06
# 3070  1.328525e+06
# 4140  9.391390e+05
# 2879  1.554987e+06
#
# [1500 rows x 1 columns]

# %%
plt.scatter(y_test,pr)
